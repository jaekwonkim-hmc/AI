# %% [markdown]
# <a href="https://colab.research.google.com/github/jaekwonkim-hmc/AI/blob/main/MLP_XOR_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [1] 필요한 패키지 불러오기

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.optimizers import SGD
import numpy as np

# %% [markdown]
# [2] XOR를  구현하기 위한 모델 구성

# %%
xor = keras.Sequential()
xor.add(keras.Input(shape=(2,)))
xor.add(Dense(4, activation='tanh'))
xor.add(Dense(1, activation='sigmoid'))
xor.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17 (68.00 B)
#  Trainable params: 17 (68.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# [3] 독립변수와 종속변수

# %%
# X : 독립변수, y : 종속변수
X = np.array([[0, 0],
              [1, 0],
              [0, 1],
              [1, 1]], dtype=np.float32)
y = np.array([[0], [1], [1], [0]], dtype=np.float32)

# %% [markdown]
# [4] 모델 컴파일 및 훈련

# %%
xor.compile(optimizer=SGD(learning_rate=0.1, momentum=0.9), loss='mse', metrics=['accuracy'])
steps = 20
format_str = 'epoch : {:4d}  손실 : {:.6f}, 정확도 : {:.6f}'
for i in range(50):
    xor.fit(X, y, verbose=0, epochs=steps)
    tr_loss, tr_acc = xor.evaluate(X, y, verbose=0)
    print(format_str.format((i+1)*steps, tr_loss, tr_acc))
# Out:
# epoch :   20  손실 : 0.236616, 정확도 : 0.500000
# epoch :   40  손실 : 0.216710, 정확도 : 0.750000
# epoch :   60  손실 : 0.180436, 정확도 : 0.750000
# epoch :   80  손실 : 0.131533, 정확도 : 1.000000
# epoch :  100  손실 : 0.078171, 정확도 : 1.000000
# epoch :  120  손실 : 0.040669, 정확도 : 1.000000
# epoch :  140  손실 : 0.022921, 정확도 : 1.000000
# epoch :  160  손실 : 0.014921, 정확도 : 1.000000
# epoch :  180  손실 : 0.010821, 정확도 : 1.000000
# epoch :  200  손실 : 0.008411, 정확도 : 1.000000
# epoch :  220  손실 : 0.006843, 정확도 : 1.000000
# epoch :  240  손실 : 0.005747, 정확도 : 1.000000
# epoch :  260  손실 : 0.004940, 정확도 : 1.000000
# epoch :  280  손실 : 0.004323, 정확도 : 1.000000
# epoch :  300  손실 : 0.003838, 정확도 : 1.000000
# epoch :  320  손실 : 0.003446, 정확도 : 1.000000
# epoch :  340  손실 : 0.003124, 정확도 : 1.000000
# epoch :  360  손실 : 0.002854, 정확도 : 1.000000
# epoch :  380  손실 : 0.002626, 정확도 : 1.000000
# epoch :  400  손실 : 0.002430, 정확도 : 1.000000
# epoch :  420  손실 : 0.002260, 정확도 : 1.000000
# epoch :  440  손실 : 0.002112, 정확도 : 1.000000
# epoch :  460  손실 : 0.001981, 정확도 : 1.000000
# epoch :  480  손실 : 0.001865, 정확도 : 1.000000
# epoch :  500  손실 : 0.001761, 정확도 : 1.000000
# epoch :  520  손실 : 0.001668, 정확도 : 1.000000
# epoch :  540  손실 : 0.001583, 정확도 : 1.000000
# epoch :  560  손실 : 0.001507, 정확도 : 1.000000
# epoch :  580  손실 : 0.001437, 정확도 : 1.000000
# epoch :  600  손실 : 0.001374, 정확도 : 1.000000
# epoch :  620  손실 : 0.001315, 정확도 : 1.000000
# epoch :  640  손실 : 0.001261, 정확도 : 1.000000
# epoch :  660  손실 : 0.001211, 정확도 : 1.000000
# epoch :  680  손실 : 0.001165, 정확도 : 1.000000
# epoch :  700  손실 : 0.001122, 정확도 : 1.000000
# epoch :  720  손실 : 0.001083, 정확도 : 1.000000
# epoch :  740  손실 : 0.001045, 정확도 : 1.000000
# epoch :  760  손실 : 0.001010, 정확도 : 1.000000
# epoch :  780  손실 : 0.000978, 정확도 : 1.000000
# epoch :  800  손실 : 0.000947, 정확도 : 1.000000
# epoch :  820  손실 : 0.000918, 정확도 : 1.000000
# epoch :  840  손실 : 0.000891, 정확도 : 1.000000
# epoch :  860  손실 : 0.000865, 정확도 : 1.000000
# epoch :  880  손실 : 0.000841, 정확도 : 1.000000
# epoch :  900  손실 : 0.000818, 정확도 : 1.000000
# epoch :  920  손실 : 0.000796, 정확도 : 1.000000
# epoch :  940  손실 : 0.000775, 정확도 : 1.000000
# epoch :  960  손실 : 0.000756, 정확도 : 1.000000
# epoch :  980  손실 : 0.000737, 정확도 : 1.000000
# epoch : 1000  손실 : 0.000719, 정확도 : 1.000000

# %% [markdown]
# [5] 훈련된 모델을 이용한 추론

# %%
print(xor.predict(X))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [[0.01259129]
#  [0.9690539 ]
#  [0.97325957]
#  [0.03231967]]
